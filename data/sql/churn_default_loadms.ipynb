# %%
# loading data from df to sql 
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Rajuujar91929394@127.0.0.1:3306/churn_def_analysis")
df_churn.to_sql(name = "bank_churn", con = engine, if_exists = "append",index = False)
df_uci.to_sql(name = "uci_credit", con = engine, if_exists = "append", index = False)

# %%
import pandas as pd 
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:Rajuujar91929394@127.0.0.1:3306/churn_def_analysis")
df_churn = pd.read_sql("SELECT * FROM bank_churn",engine)
df_uci = pd.read_sql("SELECT * FROM uci_credit",engine)

# %%
from sqlalchemy import text
with engine.connect() as conn:
    result = conn.execute(text("select count(*) from bank_churn"))
    print(result.fetchone())
# Out:
# (10127,)
